# %% [markdown]
# # Task 5 -Analyze traffic accident data to identify patterns related to road conditions, weather, and time of day. Visualize accident hotspots and contributing factors.
# Author - Neha Bansode

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("accidents.csv")
print(df)
# Out:
#       AccidentDate     Timing           State WeatherCondition  \
# 0       04-02-2013    Morning          Alaska            Rainy
# 1       23-02-2005      Night         Arizona            Clear
# 2       08-10-2014  Afternoon      California            Clear
# 3       14-01-2015      Night        Colorado            Rainy
# 4       17-01-2006  Afternoon         Georgia            Clear
# ...            ...        ...             ...              ...
# 49995   20-08-2002      Night        Virginia            Clear
# 49996   15-05-2012      Night        Virginia            Clear
# 49997   19-05-2007    Evening  North Carolina            Rainy
# 49998   04-08-2019      Night  South Carolina            Clear
# 49999   25-04-2019    Evening         Georgia            Rainy
#
#             RoadCondition  Deaths              Reason
# 0      Under Construction      10       Drunk Driving
# 1      Under Construction       3  Weather Conditions
# ...

# %%
df.head()
# Out:
#   AccidentDate     Timing       State WeatherCondition       RoadCondition  \
# 0   04-02-2013    Morning      Alaska            Rainy  Under Construction
# 1   23-02-2005      Night     Arizona            Clear  Under Construction
# 2   08-10-2014  Afternoon  California            Clear                Fine
# 3   14-01-2015      Night    Colorado            Rainy               Rough
# 4   17-01-2006  Afternoon     Georgia            Clear                Fine
#
#    Deaths              Reason
# 0      10       Drunk Driving
# 1       3  Weather Conditions
# 2       6     Poor Visibility
# 3       8     Road Conditions
# 4       2            Speeding

# %%
df.columns
# Out:
# Index(['AccidentDate', 'Timing', 'State', 'WeatherCondition', 'RoadCondition',
#        'Deaths', 'Reason'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AccidentDate      50000 non-null  object
#  1   Timing            50000 non-null  object
#  2   State             50000 non-null  object
#  3   WeatherCondition  50000 non-null  object
#  4   RoadCondition     50000 non-null  object
#  5   Deaths            50000 non-null  int64
#  6   Reason            50000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 2.7+ MB

# %%
df.shape
# Out:
# (50000, 7)

# %%
df.describe()
# Out:
#              Deaths
# count  50000.000000
# mean       4.983040
# std        3.160581
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %% [markdown]
# # Distribution of Accidents Across Different States

# %%
state_counts = df['State'].value_counts()

state_counts_df = state_counts.reset_index()
state_counts_df.columns = ['State', 'Number of Accidents']

# %%
plt.figure(figsize=(12, 8))
plt.bar(state_counts_df['State'], state_counts_df['Number of Accidents'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Number of Accidents')
plt.title('Distribution of Accidents Across Different States')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Accidents Based on Weather Conditions

# %%
weather_counts = df['WeatherCondition'].value_counts()

weather_counts_df = weather_counts.reset_index()
weather_counts_df.columns = ['WeatherCondition', 'Number of Accidents']

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='WeatherCondition', y='Number of Accidents', data=weather_counts_df, palette='viridis')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.title('Distribution of Accidents Based on Weather Conditions')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Accidents Based on Road Conditions

# %%
road_condition_counts = df['RoadCondition'].value_counts()

road_condition_counts_df = road_condition_counts.reset_index()
road_condition_counts_df.columns = ['RoadCondition', 'Number of Accidents']

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='RoadCondition', y='Number of Accidents', data=road_condition_counts_df, palette='viridis')
plt.xlabel('Road Condition')
plt.ylabel('Number of Accidents')
plt.title('Distribution of Accidents Based on Road Conditions')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Accidents Based on Timing of the Day

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="Timing", data=df, order=df['Timing'].value_counts().index)
plt.title("Distribution of Accidents Based on Timing of the Day")
plt.show()

# %% [markdown]
# # Distribution of Accidents Based on Reasons

# %%
reason_counts = df['Reason'].value_counts()

reason_counts_df = reason_counts.reset_index()
reason_counts_df.columns = ['Reason', 'Number of Accidents']

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Reason', y='Number of Accidents', data=reason_counts_df, palette='viridis')
plt.xlabel('Reason')
plt.ylabel('Number of Accidents')
plt.title('Distribution of Accidents Based on Reasons')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Accidents by Road Conditions and Timing of the Day

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.countplot(x="RoadCondition", hue="Timing", data=df, order=df['RoadCondition'].value_counts().index)
plt.title("Accidents by Road Conditions and Timing of the Day")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# # Accidents by Weather Conditions and Timing of the Day

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="WeatherCondition", hue="Timing", data=df, order=df['WeatherCondition'].value_counts().index)
plt.title("Accidents by Weather Conditions and Timing of the Day")
plt.show()

# %% [markdown]
# # Accidents by Timing of the Day

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Timing", data=df, order=df['Timing'].value_counts().index)
plt.title("Accidents by Timing of the Day")
plt.show()

# %% [markdown]
# # Accident Frequencies by State

# %%
state_accidents = df['State'].value_counts()

state_accidents_df = state_accidents.reset_index()
state_accidents_df.columns = ['State', 'Number of Accidents']

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='State', y='Number of Accidents', data=state_accidents_df, palette='viridis')
plt.xlabel('State')
plt.ylabel('Number of Accidents')
plt.title('Accident Frequencies by State')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # Number of Accidents by Reason

# %%
reason_counts = df['Reason'].value_counts()

reason_counts_df = reason_counts.reset_index()
reason_counts_df.columns = ['Reason', 'Number of Accidents']

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Number of Accidents', y='Reason', data=reason_counts_df, palette='viridis')
plt.xlabel('Number of Accidents')
plt.ylabel('Reason')
plt.title('Number of Accidents by Reason')
plt.tight_layout()
plt.show()

# %% [markdown]
# # State-wise Total Death to Accident Ratio

# %%
state_totals = df.groupby('State').agg({'Deaths': 'sum', 'State': 'count'}).rename(columns={'State': 'TotalAccidents'})

state_totals['DeathToAccidentRatio'] = state_totals['Deaths'] / state_totals['TotalAccidents']
state_totals = state_totals.reset_index()
print(state_totals)
# Out:
#              State  Deaths  TotalAccidents  DeathToAccidentRatio
# 0           Alaska    9187            1846              4.976706
# 1          Arizona    8809            1752              5.027968
# 2       California    8954            1777              5.038829
# 3         Colorado    8840            1739              5.083381
# 4          Florida    9210            1864              4.940987
# 5          Georgia    8729            1733              5.036930
# 6         Illinois    8563            1708              5.013466
# 7          Indiana    8914            1787              4.988248
# 8             Iowa    8448            1724              4.900232
# 9        Louisiana    8854            1775              4.988169
# 10        Michigan    8807            1772              4.970090
# 11       Minnesota    9031            1815              4.975758
# 12         Montana    9223            1840              5.012500
# ...

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='State', y='DeathToAccidentRatio', data=state_totals, palette='viridis')
plt.xlabel('State')
plt.ylabel('Death to Accident Ratio')
plt.title('State-wise Total Death to Accident Ratio')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()
