# %% [markdown]
# # TASK 1 - Created a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
#
# Author - Neha Bansode

# %%
#Importing all the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading the dataset
df= pd.read_csv("income.csv")
print(df)
# Out:
#      age         workclass  Unnamed: 2     education  educational-num  \
# 0     39  Self-emp-not-inc         NaN       HS-grad                9
# 1     32           Private         NaN    Assoc-acdm               12
# 2     47           Private         NaN       HS-grad                9
# 3     19           Private         NaN          12th                8
# 4     46  Self-emp-not-inc         NaN       HS-grad                9
# ..   ...               ...         ...           ...              ...
# 894   27           Private         NaN       Masters               14
# 895   17           Private         NaN          11th                7
# 896   24           Private         NaN  Some-college               10
# 897   35           Private         NaN  Some-college               10
# 898   37         Local-gov         NaN       Masters               14
#
#          marital-status         occupation relationship   race  gender  \
# 0    Married-civ-spouse       Craft-repair      Husband  White    Male
# 1    Married-civ-spouse       Craft-repair      Husband  White    Male
# 2    Married-civ-spouse       Craft-repair      Husband  Black    Male
# 3         Never-married  Handlers-cleaners    Own-child  White    Male
# 4    Married-civ-spouse    Farming-fishing      Husband  White    Male
# ..                  ...                ...          ...    ...     ...
# 894  Married-civ-spouse     Prof-specialty      Husband  White    Male
# 895       Never-married              Sales    Own-child  White  Female
# 896       Never-married       Adm-clerical    Own-child  White  Female
# 897  Married-civ-spouse       Tech-support      Husband  White    Male
# 898  Married-civ-spouse     Prof-specialty         Wife  White  Female
#
#      capital-gain  capital-loss  hours-per-week native-country
# 0               0             0              40       Portugal
# 1               0             0              42  United-States
# 2               0             0              40  United-States
# 3               0             0              20  United-States
# 4               0             0              40  United-States
# ..            ...           ...             ...            ...
# 894             0             0              55  United-States
# 895             0             0              20  United-States
# 896             0             0              40  United-States
# 897             0             0              40  United-States
# 898             0             0              45  United-States
#
# [899 rows x 14 columns]

# %%
# Count the number of each gender
gender_counts = df['gender'].value_counts()

# Plot the bar chart
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
# Plot the histogram for Age
plt.hist(df['age'], bins=5, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
